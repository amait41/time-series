# %% [markdown]
# # Pipeline + forecast

# %%
import numpy as np
import pandas as pd
print(f"Using pandas {pd.__version__}")
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

import pmdarima as pm
from sklearn.metrics import mean_squared_error
print(f"Using pmdarima {pm.__version__}")
# Using pmdarima 1.5.2

# pd.options.plotting.backend = "plotly"

ts = pd.read_pickle("orders.pkl")
trainset = ts['2021-01-04':'2021-10-10']
testset = ts["2021-10-11":]
# Out:
# Using pandas 1.3.4
# Using pmdarima 1.8.4

# %%
def title(df): return f'Nb. de commandes par jour de {df.index[0].strftime("%d-%m-%Y")} au {df.index[-1].strftime("%d-%m-%Y")}'

# %%
trainset.plot(title=title(trainset))
# Out:
# <AxesSubplot:title={'center':'Nb. de commandes par jour de 04-01-2021 au 10-10-2021'}, xlabel='ds'>

# %%
fit1 = pm.auto_arima(trainset, m=7, trace=True, suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=1759.832, Time=0.90 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=2246.100, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=1887.392, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=2035.297, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=2244.106, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=2002.396, Time=0.75 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=1760.359, Time=1.41 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=1760.663, Time=1.78 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=2161.500, Time=0.16 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=1909.670, Time=0.77 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=1778.836, Time=0.81 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=1761.680, Time=1.09 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=1762.638, Time=0.44 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=1761.966, Time=0.62 sec
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=1756.922, Time=0.68 sec
#  ARIMA(3,1,2)(0,0,1)[7] intercept   : AIC=1945.190, Time=0.65 sec
#  ARIMA(3,1,2)(1,0,0)[7] intercept   : AIC=1799.176, Time=0.44 sec
#  ARIMA(3,1,2)(2,0,1)[7] intercept   : AIC=1757.409, Time=1.18 sec
#  ARIMA(3,1,2)(1,0,2)[7] intercept   : AIC=1757.128, Time=1.17 sec
#  ARIMA(3,1,2)(0,0,0)[7] intercept   : AIC=2017.775, Time=0.21 sec
#  ARIMA(3,1,2)(0,0,2)[7] intercept   : AIC=1907.158, Time=0.68 sec
#  ARIMA(3,1,2)(2,0,0)[7] intercept   : AIC=1777.152, Time=0.79 sec
#  ARIMA(3,1,2)(2,0,2)[7] intercept   : AIC=1759.140, Time=1.31 sec
#  ARIMA(3,1,1)(1,0,1)[7] intercept   : AIC=1760.900, Time=0.50 sec
#  ARIMA(4,1,2)(1,0,1)[7] intercept   : AIC=1759.478, Time=0.81 sec
#  ARIMA(3,1,3)(1,0,1)[7] intercept   : AIC=1765.127, Time=0.83 sec
#  ARIMA(2,1,3)(1,0,1)[7] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(4,1,1)(1,0,1)[7] intercept   : AIC=1761.268, Time=0.82 sec
#  ARIMA(4,1,3)(1,0,1)[7] intercept   : AIC=1760.528, Time=0.85 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=1755.059, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,1)[7]             : AIC=1943.193, Time=0.53 sec
#  ARIMA(3,1,2)(1,0,0)[7]             : AIC=1797.283, Time=0.25 sec
#  ARIMA(3,1,2)(2,0,1)[7]             : AIC=1755.544, Time=0.68 sec
#  ARIMA(3,1,2)(1,0,2)[7]             : AIC=1755.266, Time=1.17 sec
#  ARIMA(3,1,2)(0,0,0)[7]             : AIC=2015.780, Time=0.12 sec
#  ARIMA(3,1,2)(0,0,2)[7]             : AIC=1905.181, Time=0.63 sec
#  ARIMA(3,1,2)(2,0,0)[7]             : AIC=1775.368, Time=0.75 sec
#  ARIMA(3,1,2)(2,0,2)[7]             : AIC=1757.093, Time=1.42 sec
#  ARIMA(2,1,2)(1,0,1)[7]             : AIC=1757.982, Time=0.30 sec
#  ARIMA(3,1,1)(1,0,1)[7]             : AIC=1759.018, Time=0.30 sec
#  ARIMA(4,1,2)(1,0,1)[7]             : AIC=1756.942, Time=1.02 sec
#  ARIMA(3,1,3)(1,0,1)[7]             : AIC=1757.188, Time=0.92 sec
#  ARIMA(2,1,1)(1,0,1)[7]             : AIC=1760.113, Time=0.43 sec
#  ARIMA(2,1,3)(1,0,1)[7]             : AIC=1756.700, Time=0.93 sec
#  ARIMA(4,1,1)(1,0,1)[7]             : AIC=1759.416, Time=0.39 sec
#  ARIMA(4,1,3)(1,0,1)[7]             : AIC=inf, Time=1.15 sec
#
# Best model:  ARIMA(3,1,2)(1,0,1)[7]
# Total fit time: 33.078 seconds

# %%
print(fit1.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  280
# Model:             SARIMAX(3, 1, 2)x(1, 0, [1], 7)   Log Likelihood                -869.530
# Date:                             Mon, 29 Nov 2021   AIC                           1755.059
# Time:                                     13:22:59   BIC                           1784.109
# Sample:                                          0   HQIC                          1766.712
#                                              - 280
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6296      0.093     -6.762      0.000      -0.812      -0.447
# ar.L2          0.1622      0.092      1.758      0.079      -0.019       0.343
# ar.L3         -0.1586      0.071     -2.223      0.026      -0.298      -0.019
# ma.L1          0.0445      0.072      0.620      0.535      -0.096       0.185
# ma.L2         -0.7952      0.073    -10.906      0.000      -0.938      -0.652
# ar.S.L7        0.9754      0.009    113.638      0.000       0.959       0.992
# ma.S.L7       -0.5862      0.047    -12.367      0.000      -0.679      -0.493
# sigma2        28.4489      1.438     19.778      0.000      25.630      31.268
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               544.15
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.39   Skew:                            -0.59
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Info sur les tests et en particulier Ljung-Box, Heteroskedasticity, Jarque-Bera

# %%
from pmdarima.preprocessing import LogEndogTransformer

n_orders_log, _ = LogEndogTransformer(lmbda=1e-6).fit_transform(trainset)
trainset_log = trainset.copy()
trainset_log.y = n_orders_log
trainset_log.plot(title=title(trainset_log))
# Out:
# <AxesSubplot:title={'center':'Nb. de commandes par jour de 04-01-2021 au 10-10-2021'}, xlabel='ds'>

# %%
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import LogEndogTransformer
fit2 = Pipeline([
    ('log', LogEndogTransformer()),
    ('arima', pm.AutoARIMA(trace=True,
                           suppress_warnings=True,
                           m=7))
])

fit2.fit(trainset)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=-334.517, Time=0.77 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=96.686, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=-221.246, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=-70.243, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=94.706, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=-107.023, Time=0.55 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=-327.053, Time=1.06 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=-332.063, Time=1.12 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=27.815, Time=0.24 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=-181.676, Time=0.82 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=-322.872, Time=1.35 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=-342.894, Time=1.40 sec
#  ARIMA(1,1,2)(2,0,2)[7] intercept   : AIC=-341.520, Time=1.08 sec
#  ARIMA(2,1,1)(2,0,2)[7] intercept   : AIC=-341.109, Time=1.12 sec
#  ARIMA(3,1,2)(2,0,2)[7] intercept   : AIC=inf, Time=1.41 sec
#  ARIMA(2,1,3)(2,0,2)[7] intercept   : AIC=-337.415, Time=1.77 sec
#  ARIMA(1,1,1)(2,0,2)[7] intercept   : AIC=-345.444, Time=1.77 sec
#  ARIMA(1,1,1)(1,0,2)[7] intercept   : AIC=-340.392, Time=1.47 sec
#  ARIMA(1,1,1)(2,0,1)[7] intercept   : AIC=-334.123, Time=0.81 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=-342.903, Time=0.42 sec
#  ARIMA(0,1,1)(2,0,2)[7] intercept   : AIC=-337.963, Time=0.96 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=-297.940, Time=0.68 sec
#  ARIMA(0,1,0)(2,0,2)[7] intercept   : AIC=-258.257, Time=0.50 sec
#  ARIMA(0,1,2)(2,0,2)[7] intercept   : AIC=-342.197, Time=1.08 sec
#  ARIMA(2,1,0)(2,0,2)[7] intercept   : AIC=-307.149, Time=1.82 sec
#  ARIMA(1,1,1)(2,0,2)[7]             : AIC=-347.519, Time=0.68 sec
#  ARIMA(1,1,1)(1,0,2)[7]             : AIC=-348.953, Time=0.47 sec
#  ARIMA(1,1,1)(0,0,2)[7]             : AIC=-187.532, Time=0.31 sec
#  ARIMA(1,1,1)(1,0,1)[7]             : AIC=-350.952, Time=0.29 sec
#  ARIMA(1,1,1)(0,0,1)[7]             : AIC=-104.851, Time=0.19 sec
#  ARIMA(1,1,1)(1,0,0)[7]             : AIC=-278.005, Time=0.13 sec
#  ARIMA(1,1,1)(2,0,1)[7]             : AIC=-348.953, Time=0.55 sec
#  ARIMA(1,1,1)(0,0,0)[7]             : AIC=28.067, Time=0.08 sec
#  ARIMA(1,1,1)(2,0,0)[7]             : AIC=-324.146, Time=0.46 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=-343.689, Time=0.22 sec
#  ARIMA(1,1,0)(1,0,1)[7]             : AIC=-303.808, Time=0.15 sec
#  ARIMA(2,1,1)(1,0,1)[7]             : AIC=-349.221, Time=0.27 sec
#  ARIMA(1,1,2)(1,0,1)[7]             : AIC=-349.103, Time=0.56 sec
#  ARIMA(0,1,0)(1,0,1)[7]             : AIC=-261.969, Time=0.19 sec
#  ARIMA(0,1,2)(1,0,1)[7]             : AIC=-349.438, Time=0.26 sec
#  ARIMA(2,1,0)(1,0,1)[7]             : AIC=-312.616, Time=0.17 sec
#  ARIMA(2,1,2)(1,0,1)[7]             : AIC=-353.903, Time=0.45 sec
#  ARIMA(2,1,2)(0,0,1)[7]             : AIC=-113.439, Time=0.35 sec
#  ARIMA(2,1,2)(1,0,0)[7]             : AIC=-294.625, Time=0.62 sec
#  ARIMA(2,1,2)(2,0,1)[7]             : AIC=-349.643, Time=0.75 sec
#  ARIMA(2,1,2)(1,0,2)[7]             : AIC=-351.232, Time=0.77 sec
#  ARIMA(2,1,2)(0,0,0)[7]             : AIC=25.816, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,2)[7]             : AIC=-186.554, Time=0.89 sec
#  ARIMA(2,1,2)(2,0,0)[7]             : AIC=-325.495, Time=0.59 sec
#  ARIMA(2,1,2)(2,0,2)[7]             : AIC=-347.721, Time=0.98 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=-352.039, Time=0.59 sec
#  ARIMA(2,1,3)(1,0,1)[7]             : AIC=-350.865, Time=0.50 sec
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=-352.669, Time=0.49 sec
#  ARIMA(3,1,1)(1,0,1)[7]             : AIC=-349.383, Time=0.58 sec
#  ARIMA(3,1,3)(1,0,1)[7]             : AIC=-346.916, Time=0.55 sec
#
# Best model:  ARIMA(2,1,2)(1,0,1)[7]
# Total fit time: 36.764 seconds
# Pipeline(steps=[('log', LogEndogTransformer()),
#                 ('arima', AutoARIMA(m=7, trace=True))])

# %%
from pmdarima.preprocessing import BoxCoxEndogTransformer

n_orders_bc, _ = BoxCoxEndogTransformer(lmbda2=1e-6).fit_transform(trainset)
trainset_bc = trainset.copy()
trainset_bc.y = n_orders_bc
trainset_bc.plot(title=title(trainset_bc))
# Out:
# <AxesSubplot:title={'center':'Nb. de commandes par jour de 04-01-2021 au 10-10-2021'}, xlabel='ds'>

# %%
from scipy.stats import normaltest
normaltest(trainset_bc)
# Out:
# NormaltestResult(statistic=array([3.36188465]), pvalue=array([0.18619843]))

# %%
fit3 = Pipeline([
    ('boxcox', BoxCoxEndogTransformer(lmbda2=1e-6)),
    ('arima', pm.AutoARIMA(trace=True,
                           suppress_warnings=True,
                           m=7))
])

fit3.fit(trainset)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=-1630.821, Time=0.69 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=-1346.908, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=-1641.588, Time=0.32 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=-1500.320, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=-1348.868, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=-1347.046, Time=0.07 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=-1718.424, Time=0.38 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=-1466.768, Time=0.21 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=-1692.439, Time=0.96 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=-1716.889, Time=0.79 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=-1548.581, Time=0.30 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=-1717.880, Time=0.82 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=-1669.750, Time=0.32 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=-1729.179, Time=0.47 sec
#  ARIMA(2,1,0)(0,0,1)[7] intercept   : AIC=-1465.183, Time=0.25 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=-1647.087, Time=0.36 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=-1710.802, Time=0.98 sec
#  ARIMA(2,1,0)(1,0,2)[7] intercept   : AIC=-1695.487, Time=0.72 sec
#  ARIMA(2,1,0)(0,0,0)[7] intercept   : AIC=-1346.046, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,2)[7] intercept   : AIC=-1550.266, Time=0.65 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,1,0)(2,0,2)[7] intercept   : AIC=-1721.053, Time=0.91 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=-1707.465, Time=0.55 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=-1705.311, Time=0.64 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=-1752.601, Time=0.47 sec
#  ARIMA(1,1,1)(0,0,1)[7] intercept   : AIC=-1532.861, Time=0.39 sec
#  ARIMA(1,1,1)(1,0,0)[7] intercept   : AIC=-1682.528, Time=0.38 sec
#  ARIMA(1,1,1)(2,0,1)[7] intercept   : AIC=-1722.388, Time=0.97 sec
#  ARIMA(1,1,1)(1,0,2)[7] intercept   : AIC=-1736.286, Time=0.89 sec
#  ARIMA(1,1,1)(0,0,0)[7] intercept   : AIC=-1411.891, Time=0.24 sec
#  ARIMA(1,1,1)(0,0,2)[7] intercept   : AIC=-1579.997, Time=1.21 sec
#  ARIMA(1,1,1)(2,0,0)[7] intercept   : AIC=-1727.378, Time=1.11 sec
#  ARIMA(1,1,1)(2,0,2)[7] intercept   : AIC=-1735.386, Time=1.67 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=-1722.282, Time=0.54 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=-1724.628, Time=1.63 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=-1721.393, Time=1.01 sec
#  ARIMA(1,1,1)(1,0,1)[7]             : AIC=-1755.893, Time=0.53 sec
#  ARIMA(1,1,1)(0,0,1)[7]             : AIC=-1534.858, Time=0.41 sec
#  ARIMA(1,1,1)(1,0,0)[7]             : AIC=-1688.834, Time=0.36 sec
#  ARIMA(1,1,1)(2,0,1)[7]             : AIC=-1744.008, Time=0.44 sec
#  ARIMA(1,1,1)(1,0,2)[7]             : AIC=-1739.116, Time=0.63 sec
#  ARIMA(1,1,1)(0,0,0)[7]             : AIC=-1413.889, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,2)[7]             : AIC=-1612.465, Time=0.66 sec
#  ARIMA(1,1,1)(2,0,0)[7]             : AIC=-1734.623, Time=0.63 sec
#  ARIMA(1,1,1)(2,0,2)[7]             : AIC=-1757.556, Time=0.93 sec
#  ARIMA(0,1,1)(2,0,2)[7]             : AIC=-1753.140, Time=0.73 sec
#  ARIMA(1,1,0)(2,0,2)[7]             : AIC=-1720.296, Time=0.53 sec
#  ARIMA(2,1,1)(2,0,2)[7]             : AIC=-1746.735, Time=1.18 sec
#  ARIMA(1,1,2)(2,0,2)[7]             : AIC=-1749.700, Time=0.69 sec
#  ARIMA(0,1,0)(2,0,2)[7]             : AIC=-1670.462, Time=0.35 sec
#  ARIMA(0,1,2)(2,0,2)[7]             : AIC=-1755.901, Time=1.49 sec
#  ARIMA(2,1,0)(2,0,2)[7]             : AIC=-1726.732, Time=0.68 sec
#  ARIMA(2,1,2)(2,0,2)[7]             : AIC=inf, Time=1.05 sec
#
# Best model:  ARIMA(1,1,1)(2,0,2)[7]
# Total fit time: 34.129 seconds
# Pipeline(steps=[('boxcox', BoxCoxEndogTransformer(lmbda2=1e-06)),
#                 ('arima', AutoARIMA(m=7, trace=True))])

# %%
print(fit2.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  280
# Model:             SARIMAX(2, 1, 2)x(1, 0, [1], 7)   Log Likelihood                 183.951
# Date:                             Mon, 29 Nov 2021   AIC                           -353.903
# Time:                                     13:24:11   BIC                           -328.484
# Sample:                                          0   HQIC                          -343.706
#                                              - 280
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6636      0.095     -7.006      0.000      -0.849      -0.478
# ar.L2          0.3001      0.074      4.055      0.000       0.155       0.445
# ma.L1          0.0591      0.070      0.845      0.398      -0.078       0.196
# ma.L2         -0.8146      0.050    -16.188      0.000      -0.913      -0.716
# ar.S.L7        0.9884      0.007    147.856      0.000       0.975       1.001
# ma.S.L7       -0.6798      0.052    -13.084      0.000      -0.782      -0.578
# sigma2         0.0148      0.001     15.878      0.000       0.013       0.017
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                58.50
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                            -0.21
# Prob(H) (two-sided):                  0.67   Kurtosis:                         5.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
def predict(model, trainset, testset):
    preds, conf_int = model.predict(n_periods=testset.shape[0], return_conf_int=True)

    # Print the error:
    print("Test RMSE: %.3f" % np.sqrt(mean_squared_error(testset, preds)))

    # Plot the points and the forecasts
    plt.figure(figsize=(20, 5))
    plt.plot(trainset.index.values, trainset, alpha=0.75)
    plt.plot(testset.index.values, preds, alpha=0.75, label="Prediction")
    plt.scatter(testset.index.values, testset, marker="o", label="True")
    plt.fill_between(testset.index.values, conf_int[:, 0], conf_int[:, 1], alpha=0.2, color='b', label="IC")
    plt.title(f"Prédiction sur {len(testset)} jours")
    plt.xlabel("Temps")
    plt.legend()

# %%
predict(fit1, trainset, testset)
# Out:
# Test RMSE: 4.927

# %%
predict(fit2, trainset, testset)
# Out:
# Test RMSE: 4.851

# %%
predict(fit3, trainset, testset)
# Out:
# Test RMSE: 5.499
